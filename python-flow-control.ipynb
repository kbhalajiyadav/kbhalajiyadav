# %% [markdown]
# <a href="https://www.kaggle.com/code/bhalajik/python-conditional-statements-flow-control?scriptVersionId=105198936" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # If & Indentation
#
# - The white space at the beginning of the code is called indentation.

# %%
input1 = int(input("Enter a integer"))

if input1 > 0:
    print("The number is postive")
    
elif input1 < 0:
     print("The number is not positive")  
        
else:
    print("The number is zero")
# Out:
# Enter a integer 0
# The number is zero

# %%
place = input("1. Hill Station,  2. Beach   Enter he place you would like to visit")

if place == "1" or "Hill Station":
    print("Let us! Plan our trip to Hill Station now")
    
elif place == "2" or "Beach":
        print("Let us pack our bags for the Sun View")
# Out:
# 1. Hill Station,  2. Beach   Enter he place you would like to visit Beach
# Let us! Plan our trip to Hill Station now

# %% [markdown]
# # Nested if

# %%
ask = input("We are planning to go to vist an Hill Station or  a temple would you like to join us? ")

if ask == "Yes" or ask == "yes":
    ask2 = input("Do you mind to pick a place for our visit, We are thinking about Beach and Temple ")
    
    if ask2 == "Beach" or ask2 == "beach":
        print("Let us pack our bags for the best road trip to vitness the beautiful Sun View")
   
    elif ask2 == "Temple" or ask2 == "temple":
        print("Let us witness the glorious arcitecture of the temple")
        
    else:
        print("We will try knowing others opinion before picking it up")
        
else:
    print("We will be looking ahead for you to join us")
# Out:
# We are planning to go to vist an Hill Station or  a temple would you like to join us?  yes
# Do you mind to pick a place for our visit, We are thinking about Beach and Temple  temple
# Let us witness the glorious arcitecture of the temple

# %% [markdown]
# # Finding the largest alue among the 3 values

# %%
#pseudo code
n1 = int(input("Enter your number 1"))
n2 = int(input("Enter your number 2"))
n3 = int(input("Enter your number 3"))

# Solution 1
max = n1

if max < n2:
    max = n2
if max < n3:
    max = n3
    
print(max, "Is the maximum value")
# Out:
# Enter your number 1 22
# Enter your number 2 1
# Enter your number 3 75
# 75

# %%
# solution 2
if n1 > n2 and n1 > n3:
    print( n1,"Is the maximun value")
    
elif n2 > n1 and n2 > n3:
     print(n2, "Is the maximun value")
        
elif n3 > n1 and n3 > n2:
     print(n3,"Is the maximun value")
# Out:
# 75 Is the maximun value
